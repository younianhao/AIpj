# %%
! git clone https://github.com/younianhao/AIpj.git

# %%
# !pip install thop

# %%
# %cd AIpj/pj3/RGBTCC
# %mkdir model

# %%
# !git pull

# %%
# %cd ./models/ops
# !bash ./make.sh

# %%
# !python test.py

# %%
# %cd ../.. 
! python predataset_yyy.py

# %%
! python preprocess_RGBT.py

# %%
! python predataset_RGBT_CC.py

# %%
# %cd RGBTCC
# !bash train.sh

# %%
# test.sh --model need to change
# !bash test.sh
